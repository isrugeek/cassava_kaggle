# %% [markdown]
# ## CAM (Class activation map)
# the original papercan be found here: http://cnnlocalization.csail.mit.edu/Zhou_Learning_Deep_Features_CVPR_2016_paper.pdf

# %%
from util.utils import cam ## Check the code here
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
cam("model/train-cbb-100.jpg")

# %% [markdown]
# ### Idea to train CAM from scratch ???
